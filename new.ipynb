# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
def excel_to_dataframes(file_path):
    # Read the Excel file
    xl = pd.ExcelFile(file_path)
    
    sheet_names = xl.sheet_names
    
    dfs_dict = {}
    
    for sheet_name in sheet_names:
        df = xl.parse(sheet_name)
        # Select only the first 8 columns
        while len(df.columns) < 9:
            df[len(df.columns)] = np.nan
        
        # Select only the first 9 columns
        df = df.iloc[:, :9]

        # Remove rows with at least one NaN value
        df = df.dropna()
        
        df.columns = ['STATUS', 'DATE', 'SHIFT', 'HOURS', 'RATE', 'COST', 'ON CALL', 'ROLE', 'UNIT']
        df = df[df['STATUS'].isin(['NEW', 'CURRENT', 'VACANT', 'PENDING'])]
        
        #df['HOSPITAL'] = sheet_name
        df = df.reset_index(drop=True)
        for col in df.columns:
            df[f'{col}-VALIDATE'] = True
        dfs_dict[sheet_name.strip()] = df
    
    return dfs_dict

# %%
def validate_date(df):
    # Initialize an empty list to store boolean values indicating whether each row is valid
    indices = []
    # Iterate through each row in the dataframe
    for index, row in df.iterrows():
        try:
            # Attempt to parse the date value using the specified format
            date = pd.to_datetime(row['DATE'])
            df.at[index, 'DATE'] = date.strftime('%A, %d %B %Y')
            df.at[index, 'DATE-VALIDATE'] = True
        except ValueError:
            # If parsing fails, append False to the validation list
            df.at[index, 'DATE-VALIDATE'] = False
            indices.append(index)
            print(index, "date validate failed")
    
    return df, indices

# %%
def validate_shift(df):
    # Iterate through each row in the dataframe
    indices = []
    for index, row in df.iterrows():
        shift_value = row['SHIFT']
        # Check if the shift value is in the format "HHMM-HHMM"
        shift_value = "".join(shift_value.strip().split(" "))
        if not isinstance(shift_value, str) or not len(shift_value) == 9 or not shift_value[4] == '-':
            # If the shift value is not in the correct format, set shift-validate to False for this row

            df.at[index, 'SHIFT-VALIDATE'] = False
            indices.append(index)
        else:
            # If the shift value is in the correct format, set shift-validate to True for this row
            df.at[index, 'SHIFT-VALIDATE'] = True
    
    return df, indices

# %%
def validate_hours(df):
    indices = []
    # Iterate through each row in the dataframe
    for index, row in df.iterrows():
        shift_value = row['SHIFT']
        hours_value = row['HOURS']
        # Check if the shift value is in the correct format "HHMM-HHMM"
        if not isinstance(shift_value, str) or not len(shift_value) == 9 or not shift_value[4] == '-':
            # If the shift value is not in the correct format, set hours-validate to False for this row
            df.at[index, 'HOURS-VALIDATE'] = False
            indices.append(index)
        else:
            # If the shift value is in the correct format, calculate the hours worked
            start_hour, end_hour = shift_value.split('-')
            start_hour = int(start_hour[:2]) + int(start_hour[2:]) / 60
            end_hour = int(end_hour[:2]) + int(end_hour[2:]) / 60
            hours_worked = end_hour - start_hour
            if hours_worked<0:
                hours_worked = 24 + hours_worked
            # Check if the calculated hours match the value in the HOURS column
            if hours_worked != hours_value:  # Allowing for small floating point differences
                # If the calculated hours do not match, assign the correct value
                #df.at[index, 'HOURS'] = hours_worked
                indices.append(index)
                # Set hours-validate to False for this row
                df.at[index, 'HOURS-VALIDATE'] = False
            else:
                # If the calculated hours match, set hours-validate to True for this row
                df.at[index, 'HOURS-VALIDATE'] = True
    
    return df, indices

# %%
def validate_rate(df):
    # Iterate through each row in the dataframe
    indices = []
    for index, row in df.iterrows():
        rate_value = row['RATE']
        cost_value = row['COST']
        hours_value = row['HOURS']
        
        # Check if rate equals cost and hours is not equal to 1
        if rate_value == cost_value or type(rate_value)!=type(cost_value):
            # If rate equals cost but hours is not 1, set rate-validate to False for this row
            indices.append(index)
            df.at[index, 'RATE-VALIDATE'] = False
        else:
            # Otherwise, set rate-validate to True for this row
            df.at[index, 'RATE-VALIDATE'] = True
    
    return df,indices

# %%
def validate_cost(df):
    indices = []
    for index, row in df.iterrows():
        rate_value = row['RATE']
        hours_value = row['HOURS']
        cost_value = row['COST']
        
        expected_cost = rate_value * hours_value
        if expected_cost != cost_value:
            indices.append(index)
            df.at[index, 'COST-VALIDATE'] = False
        else:
            df.at[index, 'COST-VALIDATE'] = True
    
    return df, indices

# %%
def validate_oncall(df):
    # Iterate through each row in the dataframe
    indices = []
    for index, row in df.iterrows():
        oncall_value = row['ON CALL']
        
        # Check if cost value is either 'yes' or 'no'
        try:
            if oncall_value.lower() not in ['yes', 'no']:
                # If cost value is not 'yes' or 'no', set cost-validate to False for this row
                df.at[index, 'ON CALL-VALIDATE'] = False
                indices.append(index)
            else:
                # Otherwise, set cost-validate to True for this row
                df.at[index, 'ON CALL-VALIDATE'] = True
        except:
             df.at[index, 'ON CALL-VALIDATE'] = False
    
    return df, indices

# %%
def validate_roles(df):
    valid_roles = ['CMO Senior', 'REGISTRAR', 'RMO', 'SRMO', 'CMO NON IC', 'REGISTRAR IC']
    indices = []
    # Iterate through each row in the dataframe
    for index, row in df.iterrows():
        role_value = row['ROLE']
        try:
        # Check if role value is in the predefined list of valid roles
            if role_value not in valid_roles:
                # If role value is not in the predefined list, set roles-validate to False for this row
                indices.append(index)
                df.at[index, 'ROLE-VALIDATE'] = False
            else:
                # Otherwise, set roles-validate to True for this row
                df.at[index, 'ROLE-VALIDATE'] = True
        except:
            df.at[index, 'ROLE-VALIDATE'] = False
    
    return df, indices

# %%
def validate_units(df):
    valid_units = ['ANAESTH', 'ED', 'FACILITY', 'ICU', 'MEDICAL', 'O & G', 'ONCOLOGY', 'ORTHO', 'PAEDS', 'PSYCH', 'SURGICAL', 'WARDS']
    indices = []
    # Iterate through each row in the dataframe
    for index, row in df.iterrows():
        unit_value = row['UNIT']
        try:
            # Check if unit value is in the predefined list of valid units
            if unit_value not in valid_units:
                # If unit value is not in the predefined list, set unit-validate to False for this row
                indices.append(index)
                df.at[index, 'UNIT-VALIDATE'] = False
            else:
                # Otherwise, set unit-validate to True for this row
                df.at[index, 'UNIT-VALIDATE'] = True
        except:
            df.at[index, 'UNIT-VALIDATE'] = False
    
    return df, indices

# %%
file_path = 'data/HNELHD NON-SPECIALIST LOCUM VACANCY LIST (18) (1).xlsx'  # Change this to your Excel file path
dataframes = excel_to_dataframes(file_path)

# %%
INDEX = 6
print(list(dataframes.keys())[INDEX])
dataframes[list(dataframes.keys())[INDEX]]
# Out:
# ARMIDALE DENTIST
#     STATUS                 DATE      SHIFT HOURS RATE COST ON CALL     ROLE  \
# 0   VACANT  2024-04-15 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 1   VACANT  2024-04-16 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 2   VACANT  2024-04-17 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 3   VACANT  2024-04-18 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 4   VACANT  2024-04-19 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 5   VACANT  2024-04-22 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 6   VACANT  2024-04-23 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 7   VACANT  2024-04-24 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 8   VACANT  2024-04-25 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 9   VACANT  2024-04-26 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 10  VACANT  2024-04-29 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 11  VACANT  2024-04-30 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 12  VACANT  2024-05-01 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 13  VACANT  2024-05-02 00:00:00  0800-1630     8  100  800      NO  DENTIST
# 14  VACANT  2024-05-03 00:00:00  0800-1630     8  100  800      NO  DENTIST
#
#         UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  HOURS-VALIDATE  \
# 0   ARMIDALE             True           True            True            True
# 1   ARMIDALE             True           True            True            True
# 2   ARMIDALE             True           True            True            True
# 3   ARMIDALE             True           True            True            True
# 4   ARMIDALE             True           True            True            True
# 5   ARMIDALE             True           True            True            True
# 6   ARMIDALE             True           True            True            True
# 7   ARMIDALE             True           True            True            True
# 8   ARMIDALE             True           True            True            True
# 9   ARMIDALE             True           True            True            True
# 10  ARMIDALE             True           True            True            True
# 11  ARMIDALE             True           True            True            True
# 12  ARMIDALE             True           True            True            True
# 13  ARMIDALE             True           True            True            True
# 14  ARMIDALE             True           True            True            True
#
#     RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  ROLE-VALIDATE  \
# 0            True           True              True           True
# 1            True           True              True           True
# 2            True           True              True           True
# 3            True           True              True           True
# 4            True           True              True           True
# 5            True           True              True           True
# 6            True           True              True           True
# 7            True           True              True           True
# 8            True           True              True           True
# 9            True           True              True           True
# 10           True           True              True           True
# 11           True           True              True           True
# 12           True           True              True           True
# 13           True           True              True           True
# 14           True           True              True           True
#
#     UNIT-VALIDATE
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# 5            True
# 6            True
# 7            True
# 8            True
# 9            True
# 10           True
# 11           True
# 12           True
# 13           True
# 14           True

# %%
datevalidated = {}
date_val_failed = {}
for x in dataframes.keys():
    datevalidated[x],date_val_failed[x] = validate_date(dataframes[x])

# %%
shiftvalidated = {}
shift_val_failed = {}
for x in dataframes.keys():
    shiftvalidated[x],shift_val_failed[x] = validate_shift(datevalidated[x])

# %%
hoursvalidated = {}
hours_val_failed = {}
for x in dataframes.keys():
    hoursvalidated[x],hours_val_failed[x] = validate_hours(shiftvalidated[x])

# %%
ratesvalidated = {}
rates_val_failed = {}
for x in dataframes.keys():
    ratesvalidated[x],rates_val_failed[x] = validate_rate(hoursvalidated[x])

# %%
costvalidated = {}
cost_val_failed = {}
for x in dataframes.keys():
    costvalidated[x],cost_val_failed[x] = validate_cost(ratesvalidated[x])

# %%
oncallvalidated = {}
oncall_val_failed = {}
for x in dataframes.keys():
    oncallvalidated[x],oncall_val_failed[x] = validate_oncall(costvalidated[x])

# %%
rolesvalidated = {}
roles_val_failed = {}
for x in dataframes.keys():
    rolesvalidated[x],roles_val_failed[x] = validate_roles(oncallvalidated[x])

# %%
unitvalidated = {}
unit_val_failed = {}
for x in dataframes.keys():
    unitvalidated[x],unit_val_failed[x] = validate_roles(rolesvalidated[x])

# %%
unitvalidated
# Out:
# {'MAIN MENU': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'ARMIDALE CMO ED':    STATUS                    DATE      SHIFT  HOURS   RATE    COST ON CALL  \
#  0  VACANT   Tuesday, 04 June 2024  0800-2030   12.0  250.0  3000.0     NO
#  1  VACANT  Saturday, 08 June 2024  0800-2030   12.0  250.0  3000.0     NO
#  2  VACANT    Monday, 17 June 2024  2000-0830   12.0  250.0  3000.0     NO
#  3  VACANT   Tuesday, 18 June 2024  2000-0830   12.0  250.0  3000.0     NO
#
#       ROLE UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0  CMO IC   ED             True           True            True
#  1  CMO IC   ED             True           True            True
#  2  CMO IC   ED             True           True            True
#  3  CMO IC   ED             True           True            True
#
#     HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0           False           True           True             False
#  1           False           True           True             False
#  2           False           True           True             False
#  3           False           True           True             False
#
#     ROLE-VALIDATE  UNIT-VALIDATE
#  0          False           True
#  1          False           True
#  2          False           True
#  3          False           True  ,
#  'ARMIDALE ED CMO NON IC':    STATUS                    DATE         SHIFT HOURS RATE  COST ON CALL  \
#  0  VACANT  Saturday, 29 June 2024  1200 - 0030     12  220  2640      NO
#  1  VACANT   Saturday, 04 May 2024  1200 - 0030     12  220  2640      NO
#
#           ROLE UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0  CMO NON IC   ED             True           True            True
#  1  CMO NON IC   ED             True           True            True
#
#     HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0           False           True           True              True
#  1           False           True           True              True
#
#     ROLE-VALIDATE  UNIT-VALIDATE
#  0           True           True
#  1           True           True  ,
#  'ARMIDALE ANAESTHETICS': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'ARMIDALE GEN SURG REG': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'ARMIDALE GEN MED REG': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'ARMIDALE DENTIST':     STATUS                      DATE      SHIFT HOURS RATE COST ON CALL  \
#  0   VACANT     Monday, 15 April 2024  0800-1630     8  100  800      NO
#  1   VACANT    Tuesday, 16 April 2024  0800-1630     8  100  800      NO
#  2   VACANT  Wednesday, 17 April 2024  0800-1630     8  100  800      NO
#  3   VACANT   Thursday, 18 April 2024  0800-1630     8  100  800      NO
#  4   VACANT     Friday, 19 April 2024  0800-1630     8  100  800      NO
#  5   VACANT     Monday, 22 April 2024  0800-1630     8  100  800      NO
#  6   VACANT    Tuesday, 23 April 2024  0800-1630     8  100  800      NO
#  7   VACANT  Wednesday, 24 April 2024  0800-1630     8  100  800      NO
#  8   VACANT   Thursday, 25 April 2024  0800-1630     8  100  800      NO
#  9   VACANT     Friday, 26 April 2024  0800-1630     8  100  800      NO
#  10  VACANT     Monday, 29 April 2024  0800-1630     8  100  800      NO
#  11  VACANT    Tuesday, 30 April 2024  0800-1630     8  100  800      NO
#  12  VACANT    Wednesday, 01 May 2024  0800-1630     8  100  800      NO
#  13  VACANT     Thursday, 02 May 2024  0800-1630     8  100  800      NO
#  14  VACANT       Friday, 03 May 2024  0800-1630     8  100  800      NO
#
#         ROLE      UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0   DENTIST  ARMIDALE             True           True            True
#  1   DENTIST  ARMIDALE             True           True            True
#  2   DENTIST  ARMIDALE             True           True            True
#  3   DENTIST  ARMIDALE             True           True            True
#  4   DENTIST  ARMIDALE             True           True            True
#  5   DENTIST  ARMIDALE             True           True            True
#  6   DENTIST  ARMIDALE             True           True            True
#  7   DENTIST  ARMIDALE             True           True            True
#  8   DENTIST  ARMIDALE             True           True            True
#  9   DENTIST  ARMIDALE             True           True            True
#  10  DENTIST  ARMIDALE             True           True            True
#  11  DENTIST  ARMIDALE             True           True            True
#  12  DENTIST  ARMIDALE             True           True            True
#  13  DENTIST  ARMIDALE             True           True            True
#  14  DENTIST  ARMIDALE             True           True            True
#
#      HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0            False           True           True              True
#  1            False           True           True              True
#  2            False           True           True              True
#  3            False           True           True              True
#  4            False           True           True              True
#  5            False           True           True              True
#  6            False           True           True              True
#  7            False           True           True              True
#  8            False           True           True              True
#  9            False           True           True              True
#  10           False           True           True              True
#  11           False           True           True              True
#  12           False           True           True              True
#  13           False           True           True              True
#  14           False           True           True              True
#
#      ROLE-VALIDATE  UNIT-VALIDATE
#  0           False           True
#  1           False           True
#  2           False           True
#  3           False           True
#  4           False           True
#  5           False           True
#  6           False           True
#  7           False           True
#  8           False           True
#  9           False           True
#  10          False           True
#  11          False           True
#  12          False           True
#  13          False           True
#  14          False           True  ,
#  'ARMIDALE ORTHO REG': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'ARMIDALE O&G':     STATUS                     DATE      SHIFT HOURS RATE  COST ON CALL ROLE  \
#  0   VACANT    Monday, 29 April 2024  0730-1600     8  160  1280     YES  REG
#  1   VACANT   Tuesday, 30 April 2024  0730-1600     8  160  1280      NO  REG
#  2   VACANT   Wednesday, 01 May 2024  0730-1600     8  160  1280     YES  REG
#  3   VACANT    Thursday, 02 May 2024  0730-1600     8  160  1280      NO  REG
#  4   VACANT      Friday, 03 May 2024  0730-1600     8  160  1280     YES  REG
#  5   VACANT    Saturday, 04 May 2024  0800-1200     4  180   720     YES  REG
#  6   VACANT      Sunday, 05 May 2024  0800-1200     4  180   720     YES  REG
#  7   VACANT      Monday, 06 May 2024  0730-1600     8  160  1280     YES  REG
#  8   VACANT     Tuesday, 07 May 2024  0730-1600     8  160  1280      NO  REG
#  9   VACANT   Wednesday, 08 May 2024  0730-1600     8  160  1280     YES  REG
#  10  VACANT    Thursday, 09 May 2024  0730-1600     8  160  1280      NO  REG
#  11  VACANT      Friday, 10 May 2024  0730-1600     8  160  1280     YES  REG
#  12  VACANT    Saturday, 11 May 2024  0800-1200     4  180   720     YES  REG
#  13  VACANT      Sunday, 12 May 2024  0800-1200     4  180   720     YES  REG
#  14  VACANT      Monday, 06 May 2024  0730-1600     8  160  1280      NO  REG
#  15  VACANT     Tuesday, 07 May 2024  0730-1600     8  160  1280     YES  REG
#  16  VACANT   Wednesday, 08 May 2024  0730-1600     8  160  1280      NO  REG
#  17  VACANT    Thursday, 09 May 2024  0730-1600     8  160  1280     YES  REG
#  18  VACANT      Friday, 10 May 2024  0730-1600     8  160  1280      NO  REG
#  19  VACANT     Monday, 03 June 2024  0730-1600     8  160  1280     YES  REG
#  20  VACANT    Tuesday, 04 June 2024  0730-1600     8  160  1280      NO  REG
#  21  VACANT  Wednesday, 05 June 2024  0730-1600     8  160  1280     YES  REG
#  22  VACANT   Thursday, 06 June 2024  0730-1600     8  160  1280      NO  REG
#  23  VACANT     Friday, 07 June 2024  0730-1600     8  160  1280     YES  REG
#  24  VACANT   Saturday, 08 June 2024  0800-1200     4  180   720     YES  REG
#  25  VACANT     Sunday, 09 June 2024  0800-1200     4  180   720     YES  REG
#  26  VACANT    Tuesday, 11 June 2024  0730-1600     8  160  1280      NO  REG
#  27  VACANT  Wednesday, 12 June 2024  0730-1600     8  160  1280     YES  REG
#  28  VACANT   Thursday, 13 June 2024  0730-1600     8  160  1280      NO  REG
#  29  VACANT     Friday, 14 June 2024  0730-1600     8  160  1280     YES  REG
#  30  VACANT   Saturday, 15 June 2024  0800-1200     4  180   720     YES  REG
#  31  VACANT     Sunday, 16 June 2024  0800-1200     4  180   720     YES  REG
#  32  VACANT     Monday, 17 June 2024  0730-1600     8  160  1280      NO  REG
#  33  VACANT    Tuesday, 18 June 2024  0730-1600     8  160  1280     YES  REG
#  34  VACANT  Wednesday, 19 June 2024  0730-1600     8  160  1280      NO  REG
#  35  VACANT   Thursday, 20 June 2024  0730-1600     8  160  1280     YES  REG
#  36  VACANT     Friday, 21 June 2024  0730-1600     8  160  1280      NO  REG
#
#     UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  HOURS-VALIDATE  \
#  0   O&G             True           True            True           False
#  1   O&G             True           True            True           False
#  2   O&G             True           True            True           False
#  3   O&G             True           True            True           False
#  4   O&G             True           True            True           False
#  5   O&G             True           True            True            True
#  6   O&G             True           True            True            True
#  7   O&G             True           True            True           False
#  8   O&G             True           True            True           False
#  9   O&G             True           True            True           False
#  10  O&G             True           True            True           False
#  11  O&G             True           True            True           False
#  12  O&G             True           True            True            True
#  13  O&G             True           True            True            True
#  14  O&G             True           True            True           False
#  15  O&G             True           True            True           False
#  16  O&G             True           True            True           False
#  17  O&G             True           True            True           False
#  18  O&G             True           True            True           False
#  19  O&G             True           True            True           False
#  20  O&G             True           True            True           False
#  21  O&G             True           True            True           False
#  22  O&G             True           True            True           False
#  23  O&G             True           True            True           False
#  24  O&G             True           True            True            True
#  25  O&G             True           True            True            True
#  26  O&G             True           True            True           False
#  27  O&G             True           True            True           False
#  28  O&G             True           True            True           False
#  29  O&G             True           True            True           False
#  30  O&G             True           True            True            True
#  31  O&G             True           True            True            True
#  32  O&G             True           True            True           False
#  33  O&G             True           True            True           False
#  34  O&G             True           True            True           False
#  35  O&G             True           True            True           False
#  36  O&G             True           True            True           False
#
#      RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  ROLE-VALIDATE  \
#  0            True           True              True          False
#  1            True           True              True          False
#  2            True           True              True          False
#  3            True           True              True          False
#  4            True           True              True          False
#  5            True           True              True          False
#  6            True           True              True          False
#  7            True           True              True          False
#  8            True           True              True          False
#  9            True           True              True          False
#  10           True           True              True          False
#  11           True           True              True          False
#  12           True           True              True          False
#  13           True           True              True          False
#  14           True           True              True          False
#  15           True           True              True          False
#  16           True           True              True          False
#  17           True           True              True          False
#  18           True           True              True          False
#  19           True           True              True          False
#  20           True           True              True          False
#  21           True           True              True          False
#  22           True           True              True          False
#  23           True           True              True          False
#  24           True           True              True          False
#  25           True           True              True          False
#  26           True           True              True          False
#  27           True           True              True          False
#  28           True           True              True          False
#  29           True           True              True          False
#  30           True           True              True          False
#  31           True           True              True          False
#  32           True           True              True          False
#  33           True           True              True          False
#  34           True           True              True          False
#  35           True           True              True          False
#  36           True           True              True          False
#
#      UNIT-VALIDATE
#  0            True
#  1            True
#  2            True
#  3            True
#  4            True
#  5            True
#  6            True
#  7            True
#  8            True
#  9            True
#  10           True
#  11           True
#  12           True
#  13           True
#  14           True
#  15           True
#  16           True
#  17           True
#  18           True
#  19           True
#  20           True
#  21           True
#  22           True
#  23           True
#  24           True
#  25           True
#  26           True
#  27           True
#  28           True
#  29           True
#  30           True
#  31           True
#  32           True
#  33           True
#  34           True
#  35           True
#  36           True  ,
#  'ARMIDALE PAEDS': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'BELMONT ED CMO':     STATUS       DATE      SHIFT  HOURS   RATE    COST ON CALL        ROLE  \
#  0   VACANT 2024-04-15  2200-0830   10.0  180.0  1800.0      NO      CMO IC
#  1   VACANT 2024-04-16  1230-2230   10.0  140.0  1400.0      NO      CMO IC
#  2   VACANT 2024-04-16  2200-0830   10.0  180.0  1800.0      NO      CMO IC
#  3   VACANT 2024-04-17  2200-0830   10.0  180.0  1800.0      NO      CMO IC
#  4   VACANT 2024-04-20  1230-2230   10.0  140.0  1400.0      NO      CMO IC
#  5   VACANT 2024-04-25  1230-2230   10.0  140.0  1400.0      NO      CMO IC
#  6   VACANT 2024-04-27  1230-2230   10.0  140.0  1400.0      NO      CMO IC
#  7   VACANT 2024-04-29  0800-1800   10.0   90.0   900.0      NO  CMO NON IC
#  8   VACANT 2024-05-03  1230-2230   10.0  140.0  1400.0      NO      CMO IC
#  9   VACANT 2024-05-19  1230-2230   10.0  140.0  1400.0      NO      CMO IC
#  10  VACANT 2024-05-31  1230-2230   10.0  140.0  1400.0      NO      CMO IC
#  11  VACANT 2024-06-01  1230-2230   10.0  140.0  1400.0      NO      CMO IC
#
#     UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  HOURS-VALIDATE  \
#  0    ED             True           True            True           False
#  1    ED             True           True            True            True
#  2    ED             True           True            True           False
#  3    ED             True           True            True           False
#  4    ED             True           True            True            True
#  5    ED             True           True            True            True
#  6    ED             True           True            True            True
#  7    ED             True           True            True            True
#  8    ED             True           True            True            True
#  9    ED             True           True            True            True
#  10   ED             True           True            True            True
#  11   ED             True           True            True            True
#
#      RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  ROLE-VALIDATE  \
#  0            True           True              True          False
#  1            True           True              True          False
#  2            True           True              True          False
#  3            True           True              True          False
#  4            True           True              True          False
#  5            True           True              True          False
#  6            True           True              True          False
#  7            True           True              True           True
#  8            True           True              True          False
#  9            True           True              True          False
#  10           True           True              True          False
#  11           True           True              True          False
#
#      UNIT-VALIDATE
#  0            True
#  1            True
#  2            True
#  3            True
#  4            True
#  5            True
#  6            True
#  7            True
#  8            True
#  9            True
#  10           True
#  11           True  ,
#  'CALVARY MATER ED': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'CALVARY MATER ED SRMO':   STATUS                   DATE      SHIFT HOURS            RATE  \
#  0    NEW  Sunday, 24 March 2024  2200-0800    10  $       160.00
#
#                COST ON CALL  ROLE UNIT  STATUS-VALIDATE  DATE-VALIDATE  \
#  0   $     1,600.00      NO  SRMO   ED             True           True
#
#     SHIFT-VALIDATE  HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  \
#  0            True            True           True          False
#
#     ON CALL-VALIDATE  ROLE-VALIDATE  UNIT-VALIDATE
#  0              True           True           True  ,
#  'CALVARY MATER GEN MED': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'CALVARY MATER HAEMATOLOGY': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'CALVARY  ANAES REG': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'CALVARY MATER CARDIOLOGY': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'CALVARY MATER ANAESTHETICS': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'CALVARY MATER SURGICAL': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'CESSNOCK ED': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'GLENN INNES DENTAL':     STATUS                      DATE      SHIFT HOURS RATE COST ON CALL  \
#  0   VACANT     Monday, 15 April 2024  0800-1630     8  100  800      NO
#  1   VACANT    Tuesday, 16 April 2024  0800-1630     8  100  800      NO
#  2   VACANT  Wednesday, 17 April 2024  0800-1630     8  100  800      NO
#  3   VACANT   Thursday, 18 April 2024  0800-1630     8  100  800      NO
#  4   VACANT     Friday, 19 April 2024  0800-1630     8  100  800      NO
#  5   VACANT     Monday, 22 April 2024  0800-1630     8  100  800      NO
#  6   VACANT    Tuesday, 23 April 2024  0800-1630     8  100  800      NO
#  7   VACANT  Wednesday, 24 April 2024  0800-1630     8  100  800      NO
#  8   VACANT   Thursday, 25 April 2024  0800-1630     8  100  800      NO
#  9   VACANT     Friday, 26 April 2024  0800-1630     8  100  800      NO
#  10  VACANT     Monday, 29 April 2024  0800-1630     8  100  800      NO
#  11  VACANT    Tuesday, 30 April 2024  0800-1630     8  100  800      NO
#  12  VACANT    Wednesday, 01 May 2024  0800-1630     8  100  800      NO
#  13  VACANT     Thursday, 02 May 2024  0800-1630     8  100  800      NO
#  14  VACANT       Friday, 03 May 2024  0800-1630     8  100  800      NO
#
#         ROLE        UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0   DENTIST  GLEN INNES             True           True            True
#  1   DENTIST  GLEN INNES             True           True            True
#  2   DENTIST  GLEN INNES             True           True            True
#  3   DENTIST  GLEN INNES             True           True            True
#  4   DENTIST  GLEN INNES             True           True            True
#  5   DENTIST  GLEN INNES             True           True            True
#  6   DENTIST  GLEN INNES             True           True            True
#  7   DENTIST  GLEN INNES             True           True            True
#  8   DENTIST  GLEN INNES             True           True            True
#  9   DENTIST  GLEN INNES             True           True            True
#  10  DENTIST  GLEN INNES             True           True            True
#  11  DENTIST  GLEN INNES             True           True            True
#  12  DENTIST  GLEN INNES             True           True            True
#  13  DENTIST  GLEN INNES             True           True            True
#  14  DENTIST  GLEN INNES             True           True            True
#
#      HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0            False           True           True              True
#  1            False           True           True              True
#  2            False           True           True              True
#  3            False           True           True              True
#  4            False           True           True              True
#  5            False           True           True              True
#  6            False           True           True              True
#  7            False           True           True              True
#  8            False           True           True              True
#  9            False           True           True              True
#  10           False           True           True              True
#  11           False           True           True              True
#  12           False           True           True              True
#  13           False           True           True              True
#  14           False           True           True              True
#
#      ROLE-VALIDATE  UNIT-VALIDATE
#  0           False           True
#  1           False           True
#  2           False           True
#  3           False           True
#  4           False           True
#  5           False           True
#  6           False           True
#  7           False           True
#  8           False           True
#  9           False           True
#  10          False           True
#  11          False           True
#  12          False           True
#  13          False           True
#  14          False           True  ,
#  'GLEN INNES CMO IC':     STATUS                     DATE       SHIFT HOURS   RATE   COST ON CALL  \
#  0   VACANT    Friday, 19 April 2024  Start 1800     6    525    525     YES
#  1   VACANT  Saturday, 20 April 2024   0000-0000    24   2100   2100     YES
#  2   VACANT    Sunday, 21 April 2024   0000-0000    24   2100   2100     YES
#  3   VACANT    Monday, 22 April 2024   0000-0000    24   2100   2100     YES
#  4   VACANT   Tuesday, 23 April 2024  Until 0700     7  612.5  612.5     YES
#  5   VACANT    Friday, 26 April 2024  Start 1800     6    525    525     YES
#  6   VACANT  Saturday, 27 April 2024   0000-0000    24   2100   2100     YES
#  7   VACANT    Sunday, 28 April 2024   0000-0000    24   2100   2100     YES
#  8   VACANT    Monday, 29 April 2024  Until 0700     7  612.5  612.5     YES
#  9   VACANT      Friday, 03 May 2024  Start 1800     6    525    525     YES
#  10  VACANT    Saturday, 04 May 2024   0000-0000    24   2100   2100     YES
#  11  VACANT      Sunday, 05 May 2024   0000-0000    24   2100   2100     YES
#  12  VACANT      Monday, 06 May 2024  Until 0700     7  612.5  612.5     YES
#  13  VACANT      Friday, 10 May 2024  Start 1800     6    525    525     YES
#  14  VACANT    Saturday, 11 May 2024   0000-0000    24   2100   2100     YES
#  15  VACANT      Sunday, 12 May 2024   0000-0000    24   2100   2100     YES
#  16  VACANT      Monday, 13 May 2024  Until 0700     7  612.5  612.5     YES
#  17  VACANT      Friday, 17 May 2024  Start 1800     6    525    525     YES
#  18  VACANT    Saturday, 18 May 2024   0000-0000    24   2100   2100     YES
#  19  VACANT      Sunday, 19 May 2024  Until 0700     7   2100   2100     YES
#  20  VACANT      Monday, 20 May 2024  Start 0700    17  612.5  612.5     YES
#  21  VACANT      Friday, 24 May 2024  Start 1800     6    525    525     YES
#  22  VACANT    Saturday, 25 May 2024   0000-0000    24   2100   2100     YES
#  23  VACANT      Sunday, 26 May 2024   0000-0000    24   2100   2100     YES
#  24  VACANT      Monday, 27 May 2024  Until 0700     7  612.5  612.5     YES
#  25  VACANT      Friday, 31 May 2024  Start 1800     6    525    525     YES
#  26  VACANT   Saturday, 01 June 2024   0000-0000    24   2100   2100     YES
#  27  VACANT     Sunday, 02 June 2024   0000-0000    24   2100   2100     YES
#  28  VACANT     Monday, 03 June 2024  Until 0700     7  612.5  612.5     YES
#  29  VACANT     Friday, 07 June 2024  Start 1800     6    525    525     YES
#  30  VACANT   Saturday, 08 June 2024   0000-0000    24   2100   2100     YES
#  31  VACANT     Sunday, 09 June 2024   0000-0000    24   2100   2100     YES
#  32  VACANT     Monday, 10 June 2024  Until 0700     7  612.5  612.5     YES
#  33  VACANT     Friday, 14 June 2024  Start 1800     6    525    525     YES
#  34  VACANT   Saturday, 15 June 2024   0000-0000    24   2100   2100     YES
#  35  VACANT     Sunday, 16 June 2024   0000-0000    24   2100   2100     YES
#  36  VACANT     Friday, 21 June 2024  Start 1800     6    525    525     YES
#  37  VACANT   Saturday, 22 June 2024   0000-0000    24   2100   2100     YES
#  38  VACANT     Sunday, 23 June 2024   0000-0000    24   2100   2100     YES
#
#        ROLE UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0   CMO IC   ED             True           True           False
#  1   CMO IC   ED             True           True            True
#  2   CMO IC   ED             True           True            True
#  3   CMO IC   ED             True           True            True
#  4   CMO IC   ED             True           True           False
#  5   CMO IC   ED             True           True           False
#  6   CMO IC   ED             True           True            True
#  7   CMO IC   ED             True           True            True
#  8   CMO IC   ED             True           True           False
#  9   CMO IC   ED             True           True           False
#  10  CMO IC   ED             True           True            True
#  11  CMO IC   ED             True           True            True
#  12  CMO IC   ED             True           True           False
#  13  CMO IC   ED             True           True           False
#  14  CMO IC   ED             True           True            True
#  15  CMO IC   ED             True           True            True
#  16  CMO IC   ED             True           True           False
#  17  CMO IC   ED             True           True           False
#  18  CMO IC   ED             True           True            True
#  19  CMO IC   ED             True           True           False
#  20  CMO IC   ED             True           True           False
#  21  CMO IC   ED             True           True           False
#  22  CMO IC   ED             True           True            True
#  23  CMO IC   ED             True           True            True
#  24  CMO IC   ED             True           True           False
#  25  CMO IC   ED             True           True           False
#  26  CMO IC   ED             True           True            True
#  27  CMO IC   ED             True           True            True
#  28  CMO IC   ED             True           True           False
#  29  CMO IC   ED             True           True           False
#  30  CMO IC   ED             True           True            True
#  31  CMO IC   ED             True           True            True
#  32  CMO IC   ED             True           True           False
#  33  CMO IC   ED             True           True           False
#  34  CMO IC   ED             True           True            True
#  35  CMO IC   ED             True           True            True
#  36  CMO IC   ED             True           True           False
#  37  CMO IC   ED             True           True            True
#  38  CMO IC   ED             True           True            True
#
#      HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0            False          False          False              True
#  1            False          False          False              True
#  2            False          False          False              True
#  3            False          False          False              True
#  4            False          False          False              True
#  5            False          False          False              True
#  6            False          False          False              True
#  7            False          False          False              True
#  8            False          False          False              True
#  9            False          False          False              True
#  10           False          False          False              True
#  11           False          False          False              True
#  12           False          False          False              True
#  13           False          False          False              True
#  14           False          False          False              True
#  15           False          False          False              True
#  16           False          False          False              True
#  17           False          False          False              True
#  18           False          False          False              True
#  19           False          False          False              True
#  20           False          False          False              True
#  21           False          False          False              True
#  22           False          False          False              True
#  23           False          False          False              True
#  24           False          False          False              True
#  25           False          False          False              True
#  26           False          False          False              True
#  27           False          False          False              True
#  28           False          False          False              True
#  29           False          False          False              True
#  30           False          False          False              True
#  31           False          False          False              True
#  32           False          False          False              True
#  33           False          False          False              True
#  34           False          False          False              True
#  35           False          False          False              True
#  36           False          False          False              True
#  37           False          False          False              True
#  38           False          False          False              True
#
#      ROLE-VALIDATE  UNIT-VALIDATE
#  0           False           True
#  1           False           True
#  2           False           True
#  3           False           True
#  4           False           True
#  5           False           True
#  6           False           True
#  7           False           True
#  8           False           True
#  9           False           True
#  10          False           True
#  11          False           True
#  12          False           True
#  13          False           True
#  14          False           True
#  15          False           True
#  16          False           True
#  17          False           True
#  18          False           True
#  19          False           True
#  20          False           True
#  21          False           True
#  22          False           True
#  23          False           True
#  24          False           True
#  25          False           True
#  26          False           True
#  27          False           True
#  28          False           True
#  29          False           True
#  30          False           True
#  31          False           True
#  32          False           True
#  33          False           True
#  34          False           True
#  35          False           True
#  36          False           True
#  37          False           True
#  38          False           True  ,
#  'GLOUCESTER ED CMO IC':    STATUS                   DATE      SHIFT HOURS  RATE  COST ON CALL  \
#  0  VACANT   Tuesday, 07 May 2024  0800-0800    24  2500  2500     YES
#  1  VACANT  Thursday, 09 May 2024  0800-0800    24  2500  2500     YES
#  2  VACANT    Friday, 10 May 2024  0800-0800    24  2500  2500     YES
#  3  VACANT  Saturday, 11 May 2024  0800-0800    24  2500  2500     YES
#  4  VACANT    Sunday, 12 May 2024  0800-0800    24  2500  2500     YES
#  5  VACANT    Friday, 31 May 2024  0800-0800    24  2500  2500     YES
#
#                 ROLE UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0  CMO IC or GP VMO   ED             True           True            True
#  1  CMO IC or GP VMO   ED             True           True            True
#  2  CMO IC or GP VMO   ED             True           True            True
#  3  CMO IC or GP VMO   ED             True           True            True
#  4  CMO IC or GP VMO   ED             True           True            True
#  5  CMO IC or GP VMO   ED             True           True            True
#
#     HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0           False          False          False              True
#  1           False          False          False              True
#  2           False          False          False              True
#  3           False          False          False              True
#  4           False          False          False              True
#  5           False          False          False              True
#
#     ROLE-VALIDATE  UNIT-VALIDATE
#  0          False           True
#  1          False           True
#  2          False           True
#  3          False           True
#  4          False           True
#  5          False           True  ,
#  'GUNNEDAH CMO IC': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'GUNNEDAH OBS': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'INVERELL CMO IC':      STATUS                        DATE      SHIFT HOURS RATE  COST ON CALL  \
#  0    VACANT      Tuesday, 16 April 2024  2000-0800    12  220  2640      NO
#  1    VACANT     Saturday, 22 April 2023  2000-0800    12  210  2520      NO
#  2    VACANT       Sunday, 28 April 2024  2000-0800    12  210  2520      NO
#  3    VACANT       Monday, 29 April 2024  0800-2000    12  230  2760      NO
#  4    VACANT      Tuesday, 30 April 2024  0800-2000    12  230  2760      NO
#  ..      ...                         ...        ...   ...  ...   ...     ...
#  413  VACANT  Wednesday, 08 January 2025  2000-0800    12  180  2160      NO
#  414  VACANT   Thursday, 09 January 2025  0800-2000    12  180  2160      NO
#  415  VACANT   Thursday, 09 January 2025  2000-0800    12  180  2160      NO
#  416  VACANT     Friday, 10 January 2025  0800-2000    12  180  2160      NO
#  417  VACANT     Friday, 10 January 2025  2000-0800    12  180  2160      NO
#
#             ROLE UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0    VMO/CMO IC   ED             True           True            True
#  1    VMO/CMO IC   ED             True           True            True
#  2    VMO/CMO IC   ED             True           True            True
#  3    VMO/CMO IC   ED             True           True            True
#  4    VMO/CMO IC   ED             True           True            True
#  ..          ...  ...              ...            ...             ...
#  413  VMO/CMO IC   ED             True           True            True
#  414  VMO/CMO IC   ED             True           True            True
#  415  VMO/CMO IC   ED             True           True            True
#  416  VMO/CMO IC   ED             True           True            True
#  417  VMO/CMO IC   ED             True           True            True
#
#       HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0              True           True           True              True
#  1              True           True           True              True
#  2              True           True           True              True
#  3              True           True           True              True
#  4              True           True           True              True
#  ..              ...            ...            ...               ...
#  413            True           True           True              True
#  414            True           True           True              True
#  415            True           True           True              True
#  416            True           True           True              True
#  417            True           True           True              True
#
#       ROLE-VALIDATE  UNIT-VALIDATE
#  0            False           True
#  1            False           True
#  2            False           True
#  3            False           True
#  4            False           True
#  ..             ...            ...
#  413          False           True
#  414          False           True
#  415          False           True
#  416          False           True
#  417          False           True
#
#  [418 rows x 18 columns],
#  'INVERELL O&G': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'INVERELL DENTAL':     STATUS                      DATE      SHIFT HOURS RATE COST ON CALL  \
#  0   VACANT     Monday, 15 April 2024  0800-1630     8  100  800      NO
#  1   VACANT    Tuesday, 16 April 2024  0800-1630     8  100  800      NO
#  2   VACANT  Wednesday, 17 April 2024  0800-1630     8  100  800      NO
#  3   VACANT   Thursday, 18 April 2024  0800-1630     8  100  800      NO
#  4   VACANT     Friday, 19 April 2024  0800-1630     8  100  800      NO
#  5   VACANT     Monday, 22 April 2024  0800-1630     8  100  800      NO
#  6   VACANT    Tuesday, 23 April 2024  0800-1630     8  100  800      NO
#  7   VACANT  Wednesday, 24 April 2024  0800-1630     8  100  800      NO
#  8   VACANT   Thursday, 25 April 2024  0800-1630     8  100  800      NO
#  9   VACANT     Friday, 26 April 2024  0800-1630     8  100  800      NO
#  10  VACANT     Monday, 29 April 2024  0800-1630     8  100  800      NO
#  11  VACANT    Tuesday, 30 April 2024  0800-1630     8  100  800      NO
#  12  VACANT    Wednesday, 01 May 2024  0800-1630     8  100  800      NO
#  13  VACANT     Thursday, 02 May 2024  0800-1630     8  100  800      NO
#  14  VACANT       Friday, 03 May 2024  0800-1630     8  100  800      NO
#
#         ROLE      UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0   DENTIST  INVERELL             True           True            True
#  1   DENTIST  INVERELL             True           True            True
#  2   DENTIST  INVERELL             True           True            True
#  3   DENTIST  INVERELL             True           True            True
#  4   DENTIST  INVERELL             True           True            True
#  5   DENTIST  INVERELL             True           True            True
#  6   DENTIST  INVERELL             True           True            True
#  7   DENTIST  INVERELL             True           True            True
#  8   DENTIST  INVERELL             True           True            True
#  9   DENTIST  INVERELL             True           True            True
#  10  DENTIST  INVERELL             True           True            True
#  11  DENTIST  INVERELL             True           True            True
#  12  DENTIST  INVERELL             True           True            True
#  13  DENTIST  INVERELL             True           True            True
#  14  DENTIST  INVERELL             True           True            True
#
#      HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0            False           True           True              True
#  1            False           True           True              True
#  2            False           True           True              True
#  3            False           True           True              True
#  4            False           True           True              True
#  5            False           True           True              True
#  6            False           True           True              True
#  7            False           True           True              True
#  8            False           True           True              True
#  9            False           True           True              True
#  10           False           True           True              True
#  11           False           True           True              True
#  12           False           True           True              True
#  13           False           True           True              True
#  14           False           True           True              True
#
#      ROLE-VALIDATE  UNIT-VALIDATE
#  0           False           True
#  1           False           True
#  2           False           True
#  3           False           True
#  4           False           True
#  5           False           True
#  6           False           True
#  7           False           True
#  8           False           True
#  9           False           True
#  10          False           True
#  11          False           True
#  12          False           True
#  13          False           True
#  14          False           True  ,
#  'INVERELL ANAES REG': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'JOHN HUNTER MEDICINE': Empty DataFrame
# ...
#  Index: [],
#  'TAMWORTH PALLIATIVE & ONCOLOGY': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'TAMWORTH ANAES REG': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'TAMWORTH PAEDS REG':     STATUS                      DATE      SHIFT HOURS RATE  COST ON CALL  \
#  0   VACANT  Wednesday, 17 April 2024  2200-0800    10  160  1600      NO
#  1   VACANT   Thursday, 18 April 2024  2200-0800    10  160  1600      NO
#  2   VACANT     Friday, 19 April 2024  2200-0800    10  160  1600      NO
#  3   VACANT     Friday, 26 April 2024  1400-2000     8  160  1280      NO
#  4   VACANT     Monday, 29 April 2024  2200-0800    10  160  1600      NO
#  5   VACANT    Tuesday, 30 April 2024  2200-0800    10  160  1600      NO
#  6   VACANT    Wednesday, 01 May 2024  2200-0800    10  160  1600      NO
#  7   VACANT     Thursday, 02 May 2024  2200-0800    10  160  1600      NO
#  8   VACANT       Friday, 03 May 2024  2200-0800    10  160  1600      NO
#  9   VACANT     Saturday, 04 May 2024  2000-0800    12  160  1920      NO
#  10  VACANT       Sunday, 05 May 2024  2000-0800    12  160  1920      NO
#  11  VACANT     Saturday, 11 May 2024  2000-0800    12  160  1920      NO
#  12  VACANT       Sunday, 12 May 2024  2000-0800    12  160  1920      NO
#  13  VACANT       Monday, 13 May 2024  2200-0800    10  160  1600      NO
#  14  VACANT      Tuesday, 14 May 2024  2200-0800    10  160  1600      NO
#  15  VACANT    Wednesday, 15 May 2024  2200-0800    10  160  1600      NO
#  16  VACANT     Thursday, 16 May 2024  2200-0800    10  160  1600      NO
#  17  VACANT       Friday, 17 May 2024  2200-0800    10  160  1600      NO
#
#            ROLE   UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0   REGISTRAR   PAEDS             True           True            True
#  1   REGISTRAR   PAEDS             True           True            True
#  2   REGISTRAR   PAEDS             True           True            True
#  3   REGISTRAR   PAEDS             True           True            True
#  4   REGISTRAR   PAEDS             True           True            True
#  5   REGISTRAR   PAEDS             True           True            True
#  6   REGISTRAR   PAEDS             True           True            True
#  7   REGISTRAR   PAEDS             True           True            True
#  8   REGISTRAR   PAEDS             True           True            True
#  9   REGISTRAR   PAEDS             True           True            True
#  10  REGISTRAR   PAEDS             True           True            True
#  11  REGISTRAR   PAEDS             True           True            True
#  12  REGISTRAR   PAEDS             True           True            True
#  13  REGISTRAR   PAEDS             True           True            True
#  14  REGISTRAR   PAEDS             True           True            True
#  15  REGISTRAR   PAEDS             True           True            True
#  16  REGISTRAR   PAEDS             True           True            True
#  17  REGISTRAR   PAEDS             True           True            True
#
#      HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0             True           True           True              True
#  1             True           True           True              True
#  2             True           True           True              True
#  3            False           True           True              True
#  4             True           True           True              True
#  5             True           True           True              True
#  6             True           True           True              True
#  7             True           True           True              True
#  8             True           True           True              True
#  9             True           True           True              True
#  10            True           True           True              True
#  11            True           True           True              True
#  12            True           True           True              True
#  13            True           True           True              True
#  14            True           True           True              True
#  15            True           True           True              True
#  16            True           True           True              True
#  17            True           True           True              True
#
#      ROLE-VALIDATE  UNIT-VALIDATE
#  0           False           True
#  1           False           True
#  2           False           True
#  3           False           True
#  4           False           True
#  5           False           True
#  6           False           True
#  7           False           True
#  8           False           True
#  9           False           True
#  10          False           True
#  11          False           True
#  12          False           True
#  13          False           True
#  14          False           True
#  15          False           True
#  16          False           True
#  17          False           True  ,
#  'TAMWORTH ORTHO REG':    STATUS                         DATE      SHIFT HOURS RATE  COST ON CALL  \
#  0  VACANT     Monday, 15 November 2021  0700-1530     8  160  1280      NO
#  1  VACANT    Tuesday, 16 November 2021  0700-1530     8  160  1280      NO
#  2  VACANT  Wednesday, 17 November 2021  0700-1530     8  160  1280      NO
#  3  VACANT   Thursday, 18 November 2021  0700-1530     8  160  1280      NO
#  4  VACANT   Thursday, 18 November 2021  0700-1530     8  160  1280      NO
#  5  VACANT     Friday, 19 November 2021  0700-1530     8  160  1280      NO
#  6  VACANT     Friday, 19 November 2021  0700-1530     8  160  1280      NO
#
#         ROLE   UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0  SRMO/REG  ORTHO             True           True            True
#  1  SRMO/REG  ORTHO             True           True            True
#  2  SRMO/REG  ORTHO             True           True            True
#  3  SRMO/REG  ORTHO             True           True            True
#  4  SRMO/REG  ORTHO             True           True            True
#  5  SRMO/REG  ORTHO             True           True            True
#  6  SRMO/REG  ORTHO             True           True            True
#
#     HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0           False           True           True              True
#  1           False           True           True              True
#  2           False           True           True              True
#  3           False           True           True              True
#  4           False           True           True              True
#  5           False           True           True              True
#  6           False           True           True              True
#
#     ROLE-VALIDATE  UNIT-VALIDATE
#  0          False           True
#  1          False           True
#  2          False           True
#  3          False           True
#  4          False           True
#  5          False           True
#  6          False           True  ,
#  'TENTERFIELD ED REG IC': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'TOMAREE ED':     STATUS                    DATE        SHIFT HOURS RATE  COST ON CALL  \
#  0   VACANT   Sunday, 21 April 2024  0800 - 1900    11  225  2475      No
#  1   VACANT   Monday, 29 April 2024  0800 - 1900    11  225  2475      No
#  2   VACANT   Saturday, 04 May 2024  1830 - 0830    14  225  3150      No
#  3  PENDING     Sunday, 19 May 2024  1830 - 0830    14  225  3150      No
#  4  PENDING  Wednesday, 22 May 2024  1830 - 0830    14  225  3150      No
#  5   VACANT     Sunday, 26 May 2024  1830 - 0830    14  225  3150      No
#
#                ROLE      UNIT  STATUS-VALIDATE  DATE-VALIDATE  SHIFT-VALIDATE  \
#  0  CMO IC / GP VMO    ED Day             True           True            True
#  1  CMO IC / GP VMO    ED Day             True           True            True
#  2         CMO IC    ED Night             True           True            True
#  3  CMO IC / GP VMO  ED Night             True           True            True
#  4  CMO IC / GP VMO  ED Night             True           True            True
#  5  CMO IC / GP VMO  ED Night             True           True            True
#
#     HOURS-VALIDATE  RATE-VALIDATE  COST-VALIDATE  ON CALL-VALIDATE  \
#  0           False           True           True              True
#  1           False           True           True              True
#  2           False           True           True              True
#  3           False           True           True              True
#  4           False           True           True              True
#  5           False           True           True              True
#
#     ROLE-VALIDATE  UNIT-VALIDATE
#  0          False           True
#  1          False           True
#  2          False           True
#  3          False           True
#  4          False           True
#  5          False           True  ,
#  'WINGHAM': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'WALCHA': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'WEE WAA': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH ARMIDALE': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH ISHMU': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH PECC 0800-1630': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH PECC ROTATING': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH PECC 1000-1830': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH PECC 1230-2100': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH PECC 1430-2300': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH PECC 2230-0830': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH Newcastle Inpatient Unit': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH South Unit': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH PICU': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH MHSUS': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH MHUOP': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH MORISSET': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH MANNING': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH TAMWORTH': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH JHH NEXUS': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH MORISSET FORENSIC': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'MH LAKES IPU': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'Validation data': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: [],
#  'template sheet': Empty DataFrame
#  Columns: [STATUS, DATE, SHIFT, HOURS, RATE, COST, ON CALL, ROLE, UNIT, STATUS-VALIDATE, DATE-VALIDATE, SHIFT-VALIDATE, HOURS-VALIDATE, RATE-VALIDATE, COST-VALIDATE, ON CALL-VALIDATE, ROLE-VALIDATE, UNIT-VALIDATE]
#  Index: []}

# %%
validations = [validate_date, validate_hours, validate_rate, validate_cost, validate_hours, validate_roles, validate_oncall, validate_units]
